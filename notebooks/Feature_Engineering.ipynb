# %% [markdown]
# # 🔧 Nexalyze — Feature Engineering
#
# Runs the feature engineering pipeline and previews outputs for all AI modules.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path().resolve()))
import feature_engineering
feature_engineering.main()

# %%
import pandas as pd
from pathlib import Path

pr = Path().resolve().parent / 'data' / 'processed'
feature_files = sorted(pr.glob('feature_*.csv'))
print(f'Feature datasets: {len(feature_files)}')
for f in feature_files:
    df = pd.read_csv(f, nrows=3)
    print(f'\n=== {f.name} ({sum(1 for _ in open(f))-1:,} rows, {len(df.columns)} cols) ===')
    display(df.head(2))
