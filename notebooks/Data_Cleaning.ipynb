# %% [markdown]
# # 🧹 Nexalyze — Data Cleaning
# Reads all 25 raw CSVs and applies cleaning rules, outputting to `data/processed/`

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path().resolve()))
import clean_data
clean_data.main()

# %%
# Verify all processed files exist
from pathlib import Path
import pandas as pd

proc = Path().resolve().parent / 'data' / 'processed'
files = sorted(proc.glob('*.csv'))
print(f'Processed datasets: {len(files)}')
for f in files:
    n = sum(1 for _ in open(f)) - 1
    print(f'  {f.name:<35} {n:>10,} rows')
